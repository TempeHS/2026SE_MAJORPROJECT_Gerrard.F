# %% [markdown]
# | To-do | Finished |
# | - | - |
# | -Home page that renders different redirects<br>-Create spinning asset and apply RNG <br>-Create Gauntlet gamemode<br>-Implement a log inside website so I can quickly add logs<br>-Create all databases and apply security | -Client Feedback forum |
